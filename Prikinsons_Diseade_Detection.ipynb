# %% [markdown]
# Importing dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import svm
from sklearn.metrics import  accuracy_score

# %%
#loading the dataset from csv to pandas data frame
parkinsons_data = pd.read_csv('/content/Parkinsons_Speech-Features.csv')

# %%
parkinsons_data.head()
# Out:
#    id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0   0       1  0.85247  0.71826  0.57227        240               239
# 1   0       1  0.76686  0.69481  0.53966        234               233
# 2   0       1  0.85083  0.67604  0.58982        232               231
# 3   1       0  0.41121  0.79672  0.59257        178               177
# 4   1       0  0.32790  0.79782  0.53028        236               235
#
#    meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...  \
# 0          0.008064            0.000087       0.00218  ...
# 1          0.008258            0.000073       0.00195  ...
# 2          0.008340            0.000060       0.00176  ...
# 3          0.010858            0.000183       0.00419  ...
# 4          0.008162            0.002669       0.00535  ...
#
#    tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_29  \
# 0                     1.5620                     2.6445
# 1                     1.5589                     3.6107
# 2                     1.5643                     2.3308
# 3                     3.7805                     3.5664
# 4                     6.1727                     5.8416
#
#    tqwt_kurtosisValue_dec_30  tqwt_kurtosisValue_dec_31  \
# 0                     3.8686                     4.2105
# 1                    23.5155                    14.1962
# 2                     9.4959                    10.7458
# 3                     5.2558                    14.0403
# 4                     6.0805                     5.7621
#
#    tqwt_kurtosisValue_dec_32  tqwt_kurtosisValue_dec_33  \
# 0                     5.1221                     4.4625
# 1                    11.0261                     9.5082
# 2                    11.0177                     4.8066
# 3                     4.2235                     4.6857
# 4                     7.7817                    11.6891
#
#    tqwt_kurtosisValue_dec_34  tqwt_kurtosisValue_dec_35  \
# 0                     2.6202                     3.0004
# 1                     6.5245                     6.3431
# 2                     2.9199                     3.1495
# 3                     4.8460                     6.2650
# 4                     8.2103                     5.0559
#
#    tqwt_kurtosisValue_dec_36  class
# 0                    18.9405    1.0
# 1                    45.1780    1.0
# 2                     4.7666    1.0
# 3                     4.0603    1.0
# 4                     6.1164    1.0
#
# [5 rows x 755 columns]

# %%
parkinsons_data.tail()
# Out:
#       id  gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 592  197       0  0.84948  0.70178  0.25946        362               361
# 593  197       0  0.83045  0.71832  0.26936        379               378
# 594  198       1  0.75638  0.70234  0.61218        283               282
# 595  198       1  0.39336  0.67172  0.72706        370               366
# 596  198       1  0.28655  0.71487  0.66827        285               284
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  ...  \
# 592          0.005320            0.000025       0.00060  ...
# 593          0.005089            0.000030       0.00065  ...
# 594          0.006829            0.000032       0.00126  ...
# 595          0.005110            0.002452       0.00234  ...
# 596          0.006777            0.000047       0.00132  ...
#
#      tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_29  \
# 592                    11.9630                    10.1855
# 593                     2.9116                     3.3778
# 594                     2.5011                     2.9637
# 595                     3.0564                     3.0239
# 596                        NaN                        NaN
#
#      tqwt_kurtosisValue_dec_30  tqwt_kurtosisValue_dec_31  \
# 592                     4.9705                     2.3381
# 593                     2.8492                     3.0232
# 594                     2.5929                     2.8043
# 595                     3.0174                     2.8764
# 596                        NaN                        NaN
#
#      tqwt_kurtosisValue_dec_32  tqwt_kurtosisValue_dec_33  \
# 592                     2.7773                     3.5032
# 593                     2.7581                     3.1681
# 594                     1.8700                     1.6933
# 595                     2.3192                     2.0518
# 596                        NaN                        NaN
#
#      tqwt_kurtosisValue_dec_34  tqwt_kurtosisValue_dec_35  \
# 592                     4.4156                     4.5029
# 593                     3.9787                     4.8948
# 594                     1.9482                     3.7304
# 595                     2.5146                     3.7603
# 596                        NaN                        NaN
#
#      tqwt_kurtosisValue_dec_36  class
# 592                     4.2474    1.0
# 593                     3.5699    1.0
# 594                    11.2957    0.0
# 595                     3.5972    0.0
# 596                        NaN    NaN
#
# [5 rows x 755 columns]

# %%
parkinsons_data.shape
# Out:
# (597, 755)

# %%
#getting more information about data set
parkinsons_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 597 entries, 0 to 596
# Columns: 755 entries, id to class
# dtypes: float64(750), int64(5)
# memory usage: 3.4 MB

# %%
# checking for missing values in each column
parkinsons_data.isnull().sum()
# Out:
# id                           0
# gender                       0
# PPE                          0
# DFA                          0
# RPDE                         0
#                             ..
# tqwt_kurtosisValue_dec_33    1
# tqwt_kurtosisValue_dec_34    1
# tqwt_kurtosisValue_dec_35    1
# tqwt_kurtosisValue_dec_36    1
# class                        1
# Length: 755, dtype: int64

# %%
#delete row of missing values
parkinsons_data = parkinsons_data.dropna(how='any')

# %%
parkinsons_data.shape
# Out:
# (596, 755)

# %%
#getting some statistical meaasures about dataset
parkinsons_data.describe()
# Out:
#                id      gender         PPE         DFA        RPDE   numPulses  \
# count  596.000000  596.000000  596.000000  596.000000  596.000000  596.000000
# mean    98.833893    0.546980    0.744696    0.699541    0.492103  322.105705
# std     57.398541    0.498206    0.167686    0.071713    0.137163  101.590613
# min      0.000000    0.000000    0.041551    0.545320    0.154300    2.000000
# 25%     49.000000    0.000000    0.758952    0.642498    0.388417  250.000000
# 50%     99.000000    1.000000    0.809750    0.696315    0.490845  310.000000
# 75%    148.250000    1.000000    0.833618    0.757600    0.590087  378.250000
# max    198.000000    1.000000    0.907660    0.852640    0.871230  907.000000
#
#        numPeriodsPulses  meanPeriodPulses  stdDevPeriodPulses  locPctJitter  \
# count        596.000000        596.000000          596.000000    596.000000
# mean         320.823826          0.006428            0.000401      0.002413
# std          101.695463          0.001863            0.000760      0.002669
# min            1.000000          0.002107            0.000011      0.000210
# 25%          248.750000          0.005084            0.000052      0.001018
# 50%          309.000000          0.006200            0.000080      0.001595
# 75%          377.250000          0.007641            0.000175      0.002635
# max          905.000000          0.012966            0.003483      0.027750
#
#        ...  tqwt_kurtosisValue_dec_28  tqwt_kurtosisValue_dec_29  \
# count  ...                 596.000000                 596.000000
# mean   ...                  25.183601                  22.392119
# std    ...                  41.649278                  32.284514
# min    ...                   1.520400                   1.531700
# 25%    ...                   2.395825                   3.452800
# 50%    ...                   5.457850                   7.097000
# 75%    ...                  23.158175                  27.080400
# max    ...                 212.223400                 158.979100
#
#        tqwt_kurtosisValue_dec_30  tqwt_kurtosisValue_dec_31  \
# count                 596.000000                 596.000000
# mean                   18.892698                  14.272159
# std                    25.690977                  20.480072
# min                     1.582900                   1.747200
# 25%                     3.335425                   3.067775
# 50%                     6.093150                   4.861750
# 75%                    22.783375                  14.079275
# max                   121.256900                 102.207000
#
#        tqwt_kurtosisValue_dec_32  tqwt_kurtosisValue_dec_33  \
# count                 596.000000                 596.000000
# mean                   12.491529                  12.721852
# std                    18.036664                  16.554110
# min                     1.834900                   1.628700
# 25%                     2.919300                   3.108125
# 50%                     4.254700                   4.788450
# 75%                    11.640600                  12.973375
# max                    85.571700                  73.241700
#
#        tqwt_kurtosisValue_dec_34  tqwt_kurtosisValue_dec_35  \
# count                 596.000000                 596.000000
# mean                   15.086392                  14.951157
# std                    15.870459                  14.497775
# min                     1.861700                   1.955900
# 25%                     3.673825                   3.768175
# 50%                     6.913600                   7.661650
# 75%                    22.834075                  23.033800
# max                    62.007300                  57.544300
#
#        tqwt_kurtosisValue_dec_36       class
# count                 596.000000  596.000000
# mean                   31.871954    0.765101
# std                    34.502323    0.424292
# min                     2.364000    0.000000
# 25%                     3.887600    1.000000
# 50%                    10.179150    1.000000
# 75%                    62.162125    1.000000
# max                   156.423700    1.000000
#
# [8 rows x 755 columns]

# %%
#distribution of target variavle
parkinsons_data['class'].value_counts()
# Out:
# class
# 1.0    456
# 0.0    140
# Name: count, dtype: int64

# %% [markdown]
# 1  --> Parkinsons positiove
#
# 0  --> Healthy

# %%
#grouping the dataset ont the target variable
parkinsons_data.groupby('class').mean()
# Out:
#                id    gender       PPE       DFA      RPDE   numPulses  \
# class
# 0.0    105.792857  0.400000  0.769263  0.657791  0.417945  378.600000
# 1.0     96.697368  0.592105  0.737153  0.712359  0.514871  304.760965
#
#        numPeriodsPulses  meanPeriodPulses  stdDevPeriodPulses  locPctJitter  \
# class
# 0.0          377.342857          0.005710            0.000323      0.001473
# 1.0          303.471491          0.006649            0.000425      0.002702
#
#        ...  tqwt_kurtosisValue_dec_27  tqwt_kurtosisValue_dec_28  \
# class  ...
# 0.0    ...                  52.275580                  48.781352
# 1.0    ...                  10.560897                  17.938677
#
#        tqwt_kurtosisValue_dec_29  tqwt_kurtosisValue_dec_30  \
# class
# 0.0                    34.043996                  22.700996
# 1.0                    18.814788                  17.723484
#
#        tqwt_kurtosisValue_dec_31  tqwt_kurtosisValue_dec_32  \
# class
# 0.0                    15.867008                  11.283246
# 1.0                    13.782513                  12.862492
#
#        tqwt_kurtosisValue_dec_33  tqwt_kurtosisValue_dec_34  \
# class
# 0.0                     9.588544                   9.687321
# 1.0                    13.683832                  16.744002
#
#        tqwt_kurtosisValue_dec_35  tqwt_kurtosisValue_dec_36
# class
# 0.0                     8.788060                  13.596097
# 1.0                    16.843336                  37.482963
#
# [2 rows x 754 columns]

# %% [markdown]
# Data Pre-processing
#
# Separating the features and target

# %%
x = parkinsons_data.drop(columns=['id', 'class'], axis=1)
y = parkinsons_data['class']

# %%
print(x)
# Out:
#      gender      PPE      DFA     RPDE  numPulses  numPeriodsPulses  \
# 0         1  0.85247  0.71826  0.57227        240               239
# 1         1  0.76686  0.69481  0.53966        234               233
# 2         1  0.85083  0.67604  0.58982        232               231
# 3         0  0.41121  0.79672  0.59257        178               177
# 4         0  0.32790  0.79782  0.53028        236               235
# ..      ...      ...      ...      ...        ...               ...
# 591       0  0.81847  0.73097  0.39407        354               353
# 592       0  0.84948  0.70178  0.25946        362               361
# 593       0  0.83045  0.71832  0.26936        379               378
# 594       1  0.75638  0.70234  0.61218        283               282
# 595       1  0.39336  0.67172  0.72706        370               366
#
#      meanPeriodPulses  stdDevPeriodPulses  locPctJitter  locAbsJitter  ...  \
# 0            0.008064            0.000087       0.00218      0.000018  ...
# 1            0.008258            0.000073       0.00195      0.000016  ...
# 2            0.008340            0.000060       0.00176      0.000015  ...
# 3            0.010858            0.000183       0.00419      0.000046  ...
# 4            0.008162            0.002669       0.00535      0.000044  ...
# ..                ...                 ...           ...           ...  ...
# 591          0.005451            0.000039       0.00091      0.000005  ...
# 592          0.005320            0.000025       0.00060      0.000003  ...
# 593          0.005089            0.000030       0.00065      0.000003  ...
# 594          0.006829            0.000032       0.00126      0.000009  ...
# 595          0.005110            0.002452       0.00234      0.000012  ...
#
#      tqwt_kurtosisValue_dec_27  tqwt_kurtosisValue_dec_28  \
# 0                       1.5466                     1.5620
# 1                       1.5530                     1.5589
# 2                       1.5399                     1.5643
# 3                       6.9761                     3.7805
# 4                       7.8832                     6.1727
# ..                         ...                        ...
# 591                    15.6172                    12.0898
# 592                    22.6121                    11.9630
# 593                     4.2978                     2.9116
# 594                     2.4175                     2.5011
# 595                     2.7390                     3.0564
#
#      tqwt_kurtosisValue_dec_29  tqwt_kurtosisValue_dec_30  \
# 0                       2.6445                     3.8686
# 1                       3.6107                    23.5155
# 2                       2.3308                     9.4959
# 3                       3.5664                     5.2558
# 4                       5.8416                     6.0805
# ..                         ...                        ...
# 591                     5.1716                     2.8725
# 592                    10.1855                     4.9705
# 593                     3.3778                     2.8492
# 594                     2.9637                     2.5929
# 595                     3.0239                     3.0174
#
#      tqwt_kurtosisValue_dec_31  tqwt_kurtosisValue_dec_32  \
# 0                       4.2105                     5.1221
# 1                      14.1962                    11.0261
# 2                      10.7458                    11.0177
# 3                      14.0403                     4.2235
# 4                       5.7621                     7.7817
# ..                         ...                        ...
# 591                     2.6315                     3.5231
# 592                     2.3381                     2.7773
# 593                     3.0232                     2.7581
# 594                     2.8043                     1.8700
# 595                     2.8764                     2.3192
#
#      tqwt_kurtosisValue_dec_33  tqwt_kurtosisValue_dec_34  \
# 0                       4.4625                     2.6202
# 1                       9.5082                     6.5245
# 2                       4.8066                     2.9199
# 3                       4.6857                     4.8460
# 4                      11.6891                     8.2103
# ..                         ...                        ...
# 591                     4.9477                     4.5421
# 592                     3.5032                     4.4156
# 593                     3.1681                     3.9787
# 594                     1.6933                     1.9482
# 595                     2.0518                     2.5146
#
#      tqwt_kurtosisValue_dec_35  tqwt_kurtosisValue_dec_36
# 0                       3.0004                    18.9405
# 1                       6.3431                    45.1780
# 2                       3.1495                     4.7666
# 3                       6.2650                     4.0603
# 4                       5.0559                     6.1164
# ..                         ...                        ...
# 591                     2.3775                     2.6533
# 592                     4.5029                     4.2474
# 593                     4.8948                     3.5699
# 594                     3.7304                    11.2957
# 595                     3.7603                     3.5972
#
# [596 rows x 753 columns]

# %%
print(y)
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 591    1.0
# 592    1.0
# 593    1.0
# 594    0.0
# 595    0.0
# Name: class, Length: 596, dtype: float64

# %% [markdown]
# Splitting dataset int train and test

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=5)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (596, 753) (476, 753) (120, 753)

# %% [markdown]
# Data Standardization

# %%
scaler = StandardScaler()

# %%
scaler.fit(x_train)
# Out:
# StandardScaler()

# %%
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
print(x_test)
# Out:
# [[-1.10648049  0.31276276  0.77034396 ...  1.04182478  1.57734671
#    1.78591847]
#  [-1.10648049  0.34410684 -1.83417549 ... -0.77990158 -0.85491372
#   -0.83959944]
#  [ 0.9037665  -2.17293973  0.28336536 ... -0.55299643 -0.60600268
#   -0.70158493]
#  ...
#  [-1.10648049 -2.11952498  1.13428757 ... -0.73563088 -0.27366946
#   -0.61210278]
#  [ 0.9037665   0.45625309  0.21236218 ... -0.6653764  -0.78198147
#   -0.82063151]
#  [-1.10648049  0.31214454 -1.97813479 ...  0.01261272 -0.30599751
#   -0.80659629]]

# %% [markdown]
# Model Training
#
# Support Vector Machine Model

# %%
model = svm.SVC(kernel='linear')

# %%
#training the svm model with training data
model.fit(x_train, y_train)
# Out:
# SVC(kernel='linear')

# %% [markdown]
# Model Evaluation
#
# Accuracy score

# %%
#accuracy score on training data
x_train_prediction = model.predict(x_train)
training_data_accuracy = accuracy_score(y_train, x_train_prediction)

# %%
print('Accuracy score of training data : ', training_data_accuracy)
# Out:
# Accuracy score of training data :  1.0

# %%
# accuracy score on training data
x_test_prediction = model.predict(x_test)
test_data_accuracy = accuracy_score(y_test, x_test_prediction)

# %%
print('Accuracy score of test data : ', test_data_accuracy)
# Out:
# Accuracy score of test data :  0.825

# %% [markdown]
# Build a prediction system
